# %%
# Importing the Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Loading the Libraries
df = pd.read_csv('Salary_Data.csv')

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %% [markdown]
# Just using one features to predict the class

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
# scatter plot features vs label
plt.scatter(df.iloc[:,0],df.iloc[:,1],color='Green')
plt.xlabel('Years Of Experience')
plt.ylabel('Salary')
plt.title('Years of Experience VS Salary')
plt.show()

# %%
# Splitting dataset into feature and target
X = df.iloc[:,:1].values
y = df.iloc[:,1].values

# %%
# Splitting dataset into training and testing set
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
# Training the dataset in Linear Regression
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
# Plotting the line and dataset
plt.scatter(X_train,y_train,color='blue',label='Data Points')
plt.plot(X_train,regressor.predict(X_train),color='Green',label='Regressor Line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.show()
